# %%
import pandas as pd
import kaggle

# %%
with open(kaggle.api.dataset_download_file("currie32/crimes-in-chicago"))
# Out:
# Help on KaggleApi in module kaggle.api.kaggle_api_extended object:
#
# class KaggleApi(kaggle.api.kaggle_api.KaggleApi)
#  |  NOTE: This class is auto generated by the swagger code generator program.
#  |
#  |  Do not edit the class manually.
#  |  Ref: https://github.com/swagger-api/swagger-codegen
#  |
#  |  Method resolution order:
#  |      KaggleApi
#  |      kaggle.api.kaggle_api.KaggleApi
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  authenticate(self)
#  |      authenticate the user with the Kaggle API. This method will generate
#  |      a configuration, first checking the environment for credential
#  |      variables, and falling back to looking for the .kaggle/kaggle.json
#  |      configuration file.
#  |
#  |  competition_download_cli(self, competition, competition_opt=None, file_name=None, path=None, force=False, quiet=False)
#  |      a wrapper to competition_download_files, but first will parse input
# ...
